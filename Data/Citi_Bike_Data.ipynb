# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
# Extract CSV into Dataframe
file1 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202201-citibike-tripdata.csv\JC-202201-citibike-tripdata.csv"
file2 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202202-citibike-tripdata.csv\JC-202202-citibike-tripdata.csv"
file3 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202203-citibike-tripdata.csv\JC-202203-citibike-tripdata.csv"
file4 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202204-citibike-tripdata.csv\JC-202204-citibike-tripdata.csv"
file5 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202205-citibike-tripdata.csv\JC-202205-citibike-tripdata.csv"
file6 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202206-citibike-tripdata.csv\JC-202206-citibike-tripdata.csv"
file7 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202207-citbike-tripdata.csv\JC-202207-citbike-tripdata.csv"
file8 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202208-citibike-tripdata.csv\JC-202208-citibike-tripdata.csv"
file9 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202209-citibike-tripdata.csv\JC-202209-citibike-tripdata.csv"
file10 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202210-citibike-tripdata.csv\JC-202210-citibike-tripdata.csv"
file11 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202211-citibike-tripdata.csv\JC-202211-citibike-tripdata.csv"
file12 = r"C:\Users\Toan Nguyen\Desktop\Challenges\Citi_Bike_Challenge\Data\JC-202212-citibike-tripdata.csv\JC-202212-citibike-tripdata.csv"

#Read CSV
january_trip_data = pd.read_csv(file1, encoding="UTF-8")
february_trip_data = pd.read_csv(file2, encoding="UTF-8")
march_trip_data = pd.read_csv(file3, encoding="UTF-8")
april_trip_data = pd.read_csv(file4, encoding="UTF-8")
may_trip_data = pd.read_csv(file5, encoding="UTF-8")
june_trip_data = pd.read_csv(file6, encoding="UTF-8")
july_trip_data = pd.read_csv(file7, encoding="UTF-8")
august_trip_data = pd.read_csv(file8, encoding="UTF-8")
september_trip_data = pd.read_csv(file9, encoding="UTF-8")
october_trip_data = pd.read_csv(file10, encoding="UTF-8")
november_trip_data = pd.read_csv(file11, encoding="UTF-8")
december_trip_data = pd.read_csv(file12, encoding="UTF-8")

# %%
# Merge tables
df = [january_trip_data, february_trip_data, march_trip_data, april_trip_data,
           may_trip_data, june_trip_data, july_trip_data, august_trip_data,
           september_trip_data, october_trip_data, november_trip_data, december_trip_data]

# %%
result = pd.concat(df)

# %%
result.to_csv("Trip_History_2022.csv")

# %%
# Extract CSV into Dataframe
file13 = "Trip_History_2022.csv"

# Read CSV
trip_history = pd.read_csv(file13, encoding="UTF-8")

# %%
trip_history
# Out:
#         Unnamed: 0           ride_id  rideable_type           started_at  \
# 0                0  CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1                1  BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2                2  7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3                3  6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4                4  E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...            ...               ...            ...                  ...
# 895480       48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 895481       48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 895482       48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 895483       48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 895484       48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                    ended_at                      start_station_name  \
# ...

# %%
trip_history.count()
# Out:
# Unnamed: 0            895485
# ride_id               895485
# rideable_type         895485
# started_at            895485
# ended_at              895485
# start_station_name    895475
# start_station_id      895475
# end_station_name      892281
# end_station_id        892281
# start_lat             895485
# start_lng             895485
# end_lat               893515
# end_lng               893515
# member_casual         895485
# dtype: int64
